# %%
import pandas as pd 
import scanpy as sc
# Out:
# /tmp/ipykernel_28234/3035964124.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## Check unique genes in tumor from 07 analysis in leto (before crush)

# %%
normal = pd.read_csv("/data/scratch/kvalem/projects/2023/tmp/NSCLC_gender_2023/04-tables/nsclc_gender_normal_all_genes_DESeq2_result.csv")
tumor = pd.read_csv("/data/scratch/kvalem/projects/2023/tmp/NSCLC_gender_2023/04-tables/nsclc_gender_tumor_all_genes_DESeq2_result.csv")

# %%
normal
# Out:
#               gene_id      baseMean  log2FoldChange     lfcSE       stat  \
# 0     ENSG00000156738     72.024251       27.403755  2.157917  12.235759
# 1     ENSG00000183019    100.316683      -28.368778  2.898811  -9.441381
# 2     ENSG00000175445     70.443523      -27.539646  2.898838  -9.155271
# 3     ENSG00000119535     46.377549      -27.318715  2.898864  -9.078975
# 4     ENSG00000036448     53.654805       26.991658  2.898432   8.967490
# ...               ...           ...             ...       ...        ...
# 1586  ENSG00000275302  12986.092585       -0.234313  0.433902  -0.000000
# 1587  ENSG00000275385   5616.660695        0.746777  1.724598   0.000000
# 1588  ENSG00000276070    886.172903       -0.558215  1.337941  -0.000000
# 1589  ENSG00000277632   1674.954147        0.227380  0.979916   0.000000
# 1590  ENSG00000277791   2361.951465       -0.117000  0.184965  -0.000000
#
#             pvalue          padj  weight      comparison  \
# ...

# %%
# Find unique gene names in each dataframe
unique_to_normal = normal[~normal['gene_name'].isin(tumor['gene_name'])]
unique_to_tumor = tumor[~tumor['gene_name'].isin(normal['gene_name'])]

# Combine the unique rows
unique_rows = pd.concat([unique_to_normal, unique_to_tumor], ignore_index=True)

# %%
unique_rows.to_csv("../04-tables/unique_to_tumor_DEG.csv")

# %% [markdown]
# ## new with dataset covariate

# %%
normal = pd.read_csv("/data/projects/2023/LCBiome/nsclc_gender_atlas_tmp/out/tmp/007_re_analysis_dataset/tables/deseq2_out/nsclc_gender_normal_all_genes_DESeq2_result.csv")
tumor = pd.read_csv("/data/projects/2023/LCBiome/nsclc_gender_atlas_tmp/out/tmp/007_re_analysis_dataset/tables/deseq2_out/nsclc_gender_tumor_all_genes_DESeq2_result.csv")

# %%
normal
# Out:
#               gene_id     baseMean  log2FoldChange     lfcSE       stat  \
# 0     ENSG00000129824  1782.961194       16.245399  0.732499  20.812852
# 1     ENSG00000229807  3011.604711      -12.359263  0.750086 -15.143939
# 2     ENSG00000198692   184.473312       15.633342  1.376825  10.628323
# 3     ENSG00000172673  2116.566654       10.001193  0.848817  10.604391
# 4     ENSG00000161055  1311.942042      -16.590936  1.602442  -9.729488
# ...               ...          ...             ...       ...        ...
# 8853  ENSG00000197943     7.229032        9.210170  3.138957   2.615572
# 8854  ENSG00000198959   112.392763       12.275648  3.138244   3.592980
# 8855  ENSG00000234906   135.796975       -5.156880  3.140118  -1.323797
# 8856  ENSG00000244482    11.095266       20.051702  3.140809   6.065858
# 8857  ENSG00000254415    13.627609       20.199752  3.140808   6.112997
#
#             pvalue          padj    weight      comparison  \
# ...

# %%
# Find unique gene names in each dataframe
unique_to_normal = normal[~normal['gene_name'].isin(tumor['gene_name'])]
unique_to_tumor = tumor[~tumor['gene_name'].isin(normal['gene_name'])]

# Combine the unique rows
unique_rows = pd.concat([unique_to_normal, unique_to_tumor], ignore_index=True)

# %%
unique_rows
# Out:
#              gene_id    baseMean  log2FoldChange     lfcSE      stat  \
# 0    ENSG00000130787   36.941058      -30.000000  3.078710 -9.419528
# 1    ENSG00000155545   21.301774      -30.000000  3.078711 -9.419525
# 2    ENSG00000161513   20.857746      -30.000000  3.078712 -9.419525
# 3    ENSG00000261801   19.299823      -30.000000  3.078712 -9.419524
# 4    ENSG00000198901   19.841584      -29.221272  3.078712 -9.166585
# ..               ...         ...             ...       ...       ...
# 440  ENSG00000222009   11.526992        0.099207  3.079441  0.000000
# 441  ENSG00000241644    6.475929        0.099200  3.079442  0.000000
# 442  ENSG00000246174  130.227577        0.259958  3.078527  0.000000
# 443  ENSG00000268996   10.216154       -0.394036  3.078162 -0.000000
# 444  ENSG00000273045   13.097413       -0.394072  3.078141 -0.000000
#
#            pvalue          padj  weight      comparison  \
# 0    4.531198e-21  1.131756e-18     1.0  male_vs_female
# ...

# %%
#unique_rows.to_csv("../04-tables/unique_to_tumor_DEG.csv")
